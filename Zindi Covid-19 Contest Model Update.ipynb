# %% [markdown]
# # The Model
#
# #### Author: Michael Okeyode
#
# The model is based on a Logistic Growth function. The max number of deaths over a specified period is first obtained from the function. It is then passed into Prophet as a 'cap'
#
# ## **$y(t) = \frac{c}{1 + ae^{-bt}}$**

# %%
#Load Libraries


import pandas as pd
import numpy as np
from fbprophet import Prophet
import pickle
import math
import scipy.optimize as optim
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime, timedelta
import logging
logging.getLogger('fbprophet').setLevel(logging.WARNING)

# %%
#Load Train File

train = pd.read_csv('Train as at 18th April.csv')

# %%
# Define funcion with the coefficients to estimate
def func_logistic(t, a, b, c):
    return c / (1 + a * np.exp(-b*t))

# %%
def death_cap():
    
    cap =[]
    
    for r in train['Territory'].unique():
        data = train[train['Territory']==r][['target']]   
        data = data.reset_index(drop=False)
        data.columns = ['Timestep', 'Total Cases']
        if any(data['Total Cases'] > 0):
            data1 = data[data['Total Cases']>0]
            if len(data1['Total Cases'].unique()) < 5:
                cap.append(data1['Total Cases'].max()+51)
            else:
                data1['Timestep'] = range(0, len(data1['Timestep']))
        
                # Randomly initialize the coefficients
                np.random.seed(0)
                p0 = np.random.exponential(size=3)

                # Set min bound 0 on all coefficients, and set different max bounds for each coefficient
                bounds = (0, [100000., 1000., 1000000000.])

                # Convert pd.Series to np.Array and use Scipy's curve fit to find the best Nonlinear Least Squares coefficients
                x = np.array(data1['Timestep']) + 1
                y = np.array(data1['Total Cases'])
            
                try:
                    x = x.argsort()
                    (a,b,c),cov = optim.curve_fit(func_logistic, x, y, bounds=bounds, p0=p0, maxfev=1000000)
                
                    # The time step at which the growth is fastest
                    t_fastest = np.log(a) / b
                    i_fastest = func_logistic(t_fastest, a, b, c)
                
                    res_df = data1[['Timestep', 'Total Cases']].reset_index(drop=True)
                    res_df['fastest_grow_day'] = t_fastest
                    res_df['fastest_grow_value'] = i_fastest
                    res_df['growth_stabilized'] = t_fastest <= x[-1]
                    res_df['timestep'] = x
                    res_df['res_func_logistic'] = func_logistic(x, a, b, c)
            
                    if t_fastest <= x[-1]:
                        print('Death stabilized:', r, '| Fastest grow day:', t_fastest, '| Death:', i_fastest, '| Total Days:', x[-1])
                        res_df['cap'] = func_logistic(x[-1] + 60, a, b, c)
                        print(res_df['cap'][0])
                        
                    else:
                        print('Death increasing:', r, '| Fastest grow day:', t_fastest, '| Infections:', i_fastest)
                        res_df['cap'] = func_logistic(t_fastest + 60, a, b, c)
                        print(res_df['cap'][0])
                        
                    d = res_df['cap'][0]
                    cap.append(d)    
                    
                except RuntimeError:
                    print('No fit found for: ', r)
        
        else:
            cap.append(0)
         
            
    return cap

# %%
cap = death_cap()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Death stabilized: Afghanistan | Fastest grow day: 24.659238814405448 | Death: 26.74577390549263 | Total Days: 27
# 53.48700800218842
# Death stabilized: Albania | Fastest grow day: 19.514114241637504 | Death: 12.736258259074193 | Total Days: 38
# 25.47251616304267
# Death stabilized: Algeria | Fastest grow day: 26.379638324944263 | Death: 197.30461211941414 | Total Days: 37
# 394.60920464706857
# Death stabilized: Andorra | Fastest grow day: 13.61326404931011 | Death: 17.711430134224905 | Total Days: 27
# 35.42285638834735
# Death stabilized: Argentina | Fastest grow day: 33.892325687133564 | Death: 83.55112291397104 | Total Days: 41
# 167.0992881427881
# Death stabilized: Armenia | Fastest grow day: 17.247008754044785 | Death: 13.976234992216913 | Total Days: 23
# 27.951329950853584
# Death stabilized: Australia | Fastest grow day: 35.72287408666674 | Death: 38.60298138550953 | Total Days: 48
# 77.20560699211829
# Death stabilized: Austria | Fastest grow day: 25.486178402019114 | Death: 240.93549938148524 | Total Days: 37
# 481.8702418345688
# Death increasing: Azerbaijan | Fastest grow day: 37.95237058182709 | Infections: 18.694127099283214
# 37.319206395534216
# Death stabilized: Bahamas (the) | Fastest grow day: 4.111805753293904 | Death: 4.1840543238693435 | Total Days: 17
# 8.368108647738685
# Death stabilized: Bahrain | Fastest grow day: 17.76178043118426 | Death: 4.320633238107555 | Total Days: 33
# 8.634636776447861
# Death increasing: Bangladesh | Fastest grow day: 75.66489091982774 | Infections: 37567.389904181066
# 75126.6338312038
# Death stabilized: Barbados | Fastest grow day: 2.2018028613021454 | Death: 2.5011648566893108 | Total Days: 13
# 5.002329713287504
# Death stabilized: Belarus | Fastest grow day: 12.765105898777046 | Death: 28.748784194717373 | Total Days: 18
# 57.49755968135549
# Death stabilized: Belgium | Fastest grow day: 31.66271024937736 | Death: 3470.212720333995 | Total Days: 38
# 6940.409032775626
# Death stabilized: Bolivia (Plurinational State of) | Fastest grow day: 11.6501145245311 | Death: 18.97886545627386 | Total Days: 20
# 37.957681120451944
# Death stabilized: Bosnia and Herzegovina | Fastest grow day: 14.385322164219485 | Death: 22.66057638485554 | Total Days: 28
# 45.321152544472135
# Death stabilized: Brazil | Fastest grow day: 31.27958900301417 | Death: 2173.6021447910384 | Total Days: 32
# 4347.048909551193
# Death stabilized: Bulgaria | Fastest grow day: 29.371404586101004 | Death: 25.704877118486465 | Total Days: 38
# 51.40866847452313
# Death stabilized: Burkina Faso | Fastest grow day: 20.254499118785578 | Death: 21.36164020180947 | Total Days: 31
# 42.71978779960374
# Death increasing: Cameroon | Fastest grow day: 139.04196017949673 | Infections: 153757.91362896204
# 305391.4345457699
# Death increasing: Canada | Fastest grow day: 40.28917469209254 | Infections: 1475.5966118800795
# 2951.124877712343
# Death stabilized: Chile | Fastest grow day: 21.077287021480668 | Death: 78.6874336975769 | Total Days: 27
# 157.37454795877383
# Death stabilized: China | Fastest grow day: 25.061772139637995 | Death: 1681.882757070656 | Total Days: 87
# 3363.7654018820604
# Death stabilized: Colombia | Fastest grow day: 20.060854681829586 | Death: 93.7299268810844 | Total Days: 27
# 187.4598252215912
# Death stabilized: Croatia | Fastest grow day: 25.054701978870902 | Death: 27.92173943267563 | Total Days: 30
# 55.84128754511013
# Death increasing: Cuba | Fastest grow day: 33.61974479409082 | Infections: 39.17754759948344
# 78.33435003700164
# Death stabilized: Cyprus | Fastest grow day: 6.39344597080279 | Death: 5.570912372944014 | Total Days: 27
# 11.141824745778985
# Death stabilized: Czechia | Fastest grow day: 16.938808519788225 | Death: 98.56335861858814 | Total Days: 27
# 197.12668698385627
# Death stabilized: Côte d'Ivoire | Fastest grow day: 14.904386452337546 | Death: 5.1151574515441585 | Total Days: 20
# 10.230206628672407
# Death stabilized: Democratic People's Republic of Korea (the) | Fastest grow day: 34.26357716303949 | Death: 127.8139147083848 | Total Days: 58
# 255.51774882404177
# Death stabilized: Democratic Republic of the Congo (the) | Fastest grow day: 11.193910669822225 | Death: 10.904472654779273 | Total Days: 28
# 21.808945306025866
# Death stabilized: Denmark | Fastest grow day: 22.943485159473415 | Death: 185.18318050649123 | Total Days: 35
# 370.36580715549474
# Death stabilized: Dominican Republic (the) | Fastest grow day: 23.7396059991359 | Death: 132.14116790417637 | Total Days: 32
# 264.28058122952865
# Death stabilized: Ecuador | Fastest grow day: 25.42197402405316 | Death: 252.05614545652142 | Total Days: 35
# 504.1116108274794
# Death stabilized: Egypt | Fastest grow day: 35.688947425299155 | Death: 160.9292493710713 | Total Days: 41
# 321.83035516464463
# Death stabilized: El Salvador | Fastest grow day: 4.9135160947962175 | Death: 3.2770468720937 | Total Days: 18
# 6.554093744177335
# Death stabilized: Estonia | Fastest grow day: 13.5810929429522 | Death: 19.958448854076913 | Total Days: 24
# 39.91689356709555
# Death stabilized: Finland | Fastest grow day: 24.45936332083619 | Death: 68.78917200397011 | Total Days: 28
# 137.56993859700142
# Death stabilized: France | Fastest grow day: 52.718509269186555 | Death: 10670.380821276174 | Total Days: 63
# 21340.736226959176
# Death stabilized: Germany | Fastest grow day: 32.08853031389816 | Death: 2699.5614868616317 | Total Days: 40
# 5399.092628258696
# Death stabilized: Ghana | Fastest grow day: 14.31085798957482 | Death: 5.460662952790409 | Total Days: 28
# 10.90949903093373
# Death stabilized: Greece | Fastest grow day: 21.94125521946138 | Death: 56.54207535231034 | Total Days: 38
# 113.08404350221794
# Death stabilized: Guadeloupe | Fastest grow day: 8.121922535063915 | Death: 3.998138020121778 | Total Days: 27
# 7.996276040243165
# Death increasing: Guatemala | Fastest grow day: 130.90214018561994 | Infections: 19009.81640182351
# 37826.432809432146
# Death stabilized: Guyana | Fastest grow day: 21.53164624141926 | Death: 3.3326091013241492 | Total Days: 37
# 6.665217509786692
# Death stabilized: Honduras | Fastest grow day: 18.94934333821569 | Death: 31.87950099248173 | Total Days: 23
# 63.74467373297856
# Death stabilized: Hungary | Fastest grow day: 32.127718411442196 | Death: 146.93690883407302 | Total Days: 34
# 293.86773746076676
# Death stabilized: Iceland | Fastest grow day: 23.16556661472326 | Death: 6.250415593889634 | Total Days: 32
# 12.4979384664605
# Death stabilized: India | Fastest grow day: 32.25583836775379 | Death: 327.94728304889986 | Total Days: 38
# 655.8942253386108
# Death stabilized: Indonesia | Fastest grow day: 36.77580811577105 | Death: 512.3725690551165 | Total Days: 38
# 1024.04992103453
# Death stabilized: Iran (Islamic Republic of) | Fastest grow day: 39.17553207880789 | Death: 2640.299629237838 | Total Days: 59
# 5280.365613293501
# Death stabilized: Iraq | Fastest grow day: 25.489551862594855 | Death: 43.160623348630516 | Total Days: 45
# 86.32007603289846
# Death stabilized: Ireland | Fastest grow day: 33.434136213467625 | Death: 400.56151329697934 | Total Days: 38
# 801.113498824604
# Death stabilized: Israel | Fastest grow day: 20.891478231695054 | Death: 98.88656948388142 | Total Days: 28
# 197.77249531376467
# Death stabilized: Italy | Fastest grow day: 38.6838804114143 | Death: 11835.015388692527 | Total Days: 57
# 23669.796684183424
# Death increasing: Japan | Fastest grow day: 166.57786658485628 | Infections: 108239.24061898739
# 213108.39506230247
# Death stabilized: Jordan | Fastest grow day: 3.095069435085934 | Death: 3.468525684795288 | Total Days: 22
# 6.9370513694529015
# Death stabilized: Kazakhstan | Fastest grow day: 20.06700874788466 | Death: 13.748251362053995 | Total Days: 24
# 27.4956788331309
# Death stabilized: Kenya | Fastest grow day: 14.13162745780395 | Death: 6.691780015577755 | Total Days: 23
# 13.383540581824459
# Death increasing: Kuwait | Fastest grow day: 57.0791065408495 | Infections: 16957.91184897336
# 33915.63553403528
# Death stabilized: Lebanon | Fastest grow day: 19.547724000275686 | Death: 11.127340735152561 | Total Days: 39
# 22.25466891035367
# Death stabilized: Liberia | Fastest grow day: 3.7438485667400667 | Death: 3.580607727268408 | Total Days: 14
# 7.161215410272536
# Death stabilized: Lithuania | Fastest grow day: 23.65868626035991 | Death: 26.751730985650337 | Total Days: 28
# 53.49525776140366
# Death stabilized: Luxembourg | Fastest grow day: 23.056055613826175 | Death: 42.33489718712296 | Total Days: 35
# 84.66919858420134
# Death stabilized: Malaysia | Fastest grow day: 14.883331907917606 | Death: 43.33589508031706 | Total Days: 32
# 86.67175674889832
# Death stabilized: Mali | Fastest grow day: 13.82081305368525 | Death: 9.291686418662936 | Total Days: 20
# 18.58324379082612
# Death stabilized: Mauritius | Fastest grow day: 9.961089908035534 | Death: 4.624018045013427 | Total Days: 28
# 9.248035886303336
# Death stabilized: Mexico | Fastest grow day: 28.05926115228676 | Death: 448.1667077734985 | Total Days: 30
# 896.3316955601408
# Death increasing: Montenegro | Fastest grow day: 163.52307227224813 | Infections: 38105.23810565301
# 75111.21376149703
# Death stabilized: Morocco | Fastest grow day: 26.308889777940703 | Death: 72.11086245916287 | Total Days: 39
# 144.2217109843603
# Death stabilized: Netherlands (the) | Fastest grow day: 31.030282505543518 | Death: 1914.346552678695 | Total Days: 43
# 3828.6833389521516
# Death stabilized: New Zealand | Fastest grow day: 15.322750407455807 | Death: 6.415204759319552 | Total Days: 20
# 12.830409518628084
# Death stabilized: Niger (the) | Fastest grow day: 12.198933070918772 | Death: 8.695075094055445 | Total Days: 24
# 17.39014515216617
# Death increasing: Nigeria | Fastest grow day: 43.577337671739414 | Infections: 83.94799857055074
# 167.7714010594513
# Death stabilized: North Macedonia | Fastest grow day: 17.421829122902917 | Death: 27.978066888315336 | Total Days: 27
# 55.95609410894767
# Death stabilized: Norway | Fastest grow day: 24.663670368973147 | Death: 93.6833851247589 | Total Days: 35
# 187.36625979941763
# Death increasing: Oman | Fastest grow day: 27.282579166180494 | Infections: 11.0204761094876
# 22.011726556888423
# Death stabilized: Pakistan | Fastest grow day: 28.40067399485818 | Death: 126.90277928825894 | Total Days: 30
# 253.75826912867143
# Death stabilized: Panama | Fastest grow day: 30.02771435500996 | Death: 71.09985105933038 | Total Days: 38
# 142.19732660996857
# Death increasing: Paraguay | Fastest grow day: 40.15524006022072 | Infections: 14.325386680851524
# 28.25593914385215
# Death stabilized: Peru | Fastest grow day: 25.574038579245578 | Death: 252.85192875263655 | Total Days: 29
# 505.69740891673763
# Death stabilized: Philippines (the) | Fastest grow day: 71.71337908690546 | Death: 316.3701427458232 | Total Days: 76
# 632.6378303658024
# Death stabilized: Poland | Fastest grow day: 30.382407934216427 | Death: 216.56088056477077 | Total Days: 37
# 433.1211392671965
# Death stabilized: Portugal | Fastest grow day: 22.458599551253215 | Death: 397.349257426132 | Total Days: 32
# 794.6939855444847
# Death stabilized: Qatar | Fastest grow day: 7.357429895702385 | Death: 3.7537392459381236 | Total Days: 21
# 7.5074784857518475
# Death stabilized: Republic of Moldova (the) | Fastest grow day: 25.850173967068017 | Death: 38.835696270358355 | Total Days: 31
# 77.67118112090806
# Death stabilized: Romania | Fastest grow day: 17.815909341720268 | Death: 242.93718089486103 | Total Days: 27
# 485.8737307766859
# Death increasing: Russian Federation (the) | Fastest grow day: 39.7532804458549 | Infections: 968.8182286818299
# 1937.5602763114885
# Death stabilized: San Marino | Fastest grow day: 21.35987507469938 | Death: 18.727544996963754 | Total Days: 46
# 37.455022239355955
# Death stabilized: Saudi Arabia | Fastest grow day: 18.593602596848783 | Death: 59.798647854750776 | Total Days: 25
# 119.59641425929453
# Death stabilized: Serbia | Fastest grow day: 18.688454504019404 | Death: 60.98081006381605 | Total Days: 29
# 121.96155221987168
# Death stabilized: Singapore | Fastest grow day: 24.628210621624476 | Death: 9.621489036727944 | Total Days: 28
# 19.215088948410923
# Death increasing: Slovakia | Fastest grow day: 51.9810784379365 | Infections: 5176.558293160147
# 10353.099058030271
# Death stabilized: Slovenia | Fastest grow day: 25.198372897469458 | Death: 38.921716833383954 | Total Days: 35
# 77.8433012673916
# Death stabilized: Somalia | Fastest grow day: 8.355593603378352 | Death: 5.357798140771927 | Total Days: 10
# 10.71559628144228
# Death increasing: South Africa | Fastest grow day: 29.68739229613523 | Infections: 108.98138321525893
# 217.92951297835714
# Death increasing: South Sudan | Fastest grow day: 116.14875357780724 | Infections: 9900.912438831985
# 19750.22155550379
# Death stabilized: Spain | Fastest grow day: 30.225683707069358 | Death: 10180.133774323529 | Total Days: 46
# 20360.254052461732
# Death stabilized: Sri Lanka | Fastest grow day: 5.083343223394295 | Death: 3.573604604734407 | Total Days: 21
# 7.147209209463138
# Death stabilized: Sweden | Fastest grow day: 32.4863592115284 | Death: 1002.6928941963041 | Total Days: 38
# 2005.364550222619
# Death stabilized: Switzerland | Fastest grow day: 31.42760635625083 | Death: 732.1586123603186 | Total Days: 44
# 1464.3138352256308
# Death stabilized: Thailand | Fastest grow day: 36.43989840776597 | Death: 25.565156261082617 | Total Days: 48
# 51.13028709437781
# Death stabilized: Trinidad and Tobago | Fastest grow day: 6.118237775468738 | Death: 4.111434292909293 | Total Days: 24
# 8.222868585781546
# Death stabilized: Tunisia | Fastest grow day: 17.97868952822096 | Death: 21.00605573263414 | Total Days: 30
# 42.011968456827006
# Death stabilized: Turkey | Fastest grow day: 25.79943844608459 | Death: 1203.7733037923044 | Total Days: 32
# 2407.536281838702
# Death stabilized: Ukraine | Fastest grow day: 31.54525761885457 | Death: 95.98555749029593 | Total Days: 36
# 191.9691252196096
# Death increasing: United Arab Emirates (the) | Fastest grow day: 31.472600546022125 | Infections: 47.78058916363077
# 95.53965669915712
# Death stabilized: United Kingdom of Great Britain and Northern Ireland (the) | Fastest grow day: 36.182653021492044 | Death: 9039.427894084494 | Total Days: 44
# 18078.839194622393
# Death stabilized: United States of America (the) | Fastest grow day: 46.42673132766809 | Death: 31252.219010297104 | Total Days: 49
# 62502.97930958498
# Death stabilized: Uruguay | Fastest grow day: 5.535116488407305 | Death: 4.177926772996289 | Total Days: 20
# 8.355853545960223
# Death increasing: Uzbekistan | Fastest grow day: 52.92201393347637 | Infections: 16.887918042628186
# 32.80034408382502
# Death stabilized: Venezuela (Bolivarian Republic of) | Fastest grow day: 5.485154728512385 | Death: 4.568728990467412 | Total Days: 22
# 9.13745798092769

# %%
uniq_terr = train['Territory'].unique()

# %%
cap_check = pd.DataFrame({'Territory':uniq_terr, 'cap': cap})

# %%
train = train.merge(cap_check, on='Territory', how='left')

# %%
train.head(2)
# Out:
#         Territory X Date  target  cases    Territory     Date        cap
# 0  Afghanistan X 1/22/20       0      0  Afghanistan  1/22/20  53.487008
# 1  Afghanistan X 1/23/20       0      0  Afghanistan  1/23/20  53.487008

# %% [markdown]
# ### Model With Prophet

# %%
from tqdm import tqdm as tqdm

collect = []

for r in tqdm(train['Territory'].unique()):
    if train[train['Territory']==r]['cap'].iloc[0] > 0:
        try:
            to_check = train[train['Territory']==r][['Date', 'target' ,'cap']]
            to_check = to_check[to_check['target']>0]
            to_check.columns = ['ds', 'y', 'cap']
            to_check['ds'] = pd.to_datetime(to_check['ds'])
            to_check['weekday'] = to_check['ds'].apply(lambda x: pd.Timestamp(x).dayofweek)
            m = Prophet(interval_width=0.95, growth='logistic')
            m.add_regressor('weekday')
            m.fit(to_check)
            future = m.make_future_dataframe(periods=51)
            future['cap'] = to_check['cap'].iloc[0]
            future['weekday'] = future['ds'].apply(lambda x: pd.Timestamp(x).dayofweek)
            forecast = m.predict(future)[['ds', 'yhat']][-51:]
            ter_targ =[]
            for d in forecast['ds']:
                a = r + ' X ' + str(d.strftime('%#m/%#d/%y'))
                ter_targ.append(a)
            forecast['Territory X Date'] = ter_targ
            forecast['target'] = forecast['yhat']
            fin_df = forecast.drop(['ds', 'yhat'], axis=1)
            
            to_targ = []
            for e in to_check['ds']:
                b = r + ' X ' + str(e.strftime('%#m/%#d/%y'))
                to_targ.append(b)
            to_check['Territory X Date'] = to_targ
            to_check['target'] = to_check['y']
            to_df = to_check[['Territory X Date', 'target']]
            final_df = pd.concat([to_df, fin_df], axis=0)
            collect.append(final_df)
            
        except:
            dates = pd.date_range(start='2020-04-19', end='2020-06-08', freq='1d')        
            exc_targ =[]
            for d in dates:
                a = r + ' X ' + str(d.strftime('%#m/%#d/%y'))
                exc_targ.append(a)
            fin_df = pd.DataFrame(exc_targ, columns=['Territory X Date'])
            fin_df['target'] = to_check['cap'].iloc[0]
            to_targ = []
            for e in to_check['ds']:
                b = r + ' X ' + str(e.strftime('%#m/%#d/%y'))
                to_targ.append(b)
            to_check['Territory X Date'] = to_targ
            to_check['target'] = to_check['y']
            to_df = to_check[['Territory X Date', 'target']]
            final_df = pd.concat([to_df, fin_df], axis=0)
            
            collect.append(final_df)
            
    else:
        to_check = train[train['Territory']==r][['Date', 'target']]        
        to_check.columns = ['ds', 'y']
        to_check['ds'] = pd.to_datetime(to_check['ds'])
        m = Prophet(interval_width=0.95)
        m.fit(to_check)
        future = m.make_future_dataframe(periods=51)
        forecast = future[-51:]
        ter_targ =[]
        for d in forecast['ds']:
            a = r + ' X ' + str(d.strftime('%#m/%#d/%y'))
            ter_targ.append(a)
        forecast['Territory X Date'] = ter_targ
        forecast['target'] = 0
        fin_df = forecast.drop(['ds'], axis=1)
        collect.append(fin_df)
# Out:
#   0%|                                                                                          | 0/209 [00:00<?, ?it/s]INFO:numexpr.utils:Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
#  10%|████████▏                                                                        | 21/209 [01:13<11:03,  3.53s/it]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:69: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:70: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 209/209 [13:18<00:00,  3.82s/it]

# %%
df = collect[0]

for i in range(1,len(collect)):
     df = pd.concat([df, collect[i]], axis=0)

# %%
df = df.reset_index(drop=True)

# %%
df['Territory'] = df['Territory X Date'].apply(lambda x: x.split(' X ')[0])

# %% [markdown]
# ### Correct Predictions

# %%
new_df = []


for r in tqdm(df['Territory'].unique()):
    correct = df[df['Territory']==r][['Territory X Date', 'target', 'Territory']]
    for i in range(1, len(correct)):
        if correct['target'].iloc[i] < correct['target'].iloc[i-1]:
            correct['target'].iloc[i] = correct['target'].iloc[i] + (correct['target'].iloc[i-1] - correct['target'].iloc[i])
    new_df.append(correct)
# Out:
#   0%|                                                                                          | 0/209 [00:00<?, ?it/s]C:\Users\THIS PC\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 100%|███████████████████████████████████████████████████████████████████████████████| 209/209 [00:01<00:00, 161.86it/s]

# %%
pred = new_df[0]

for i in range(1,len(new_df)):
    pred = pd.concat([pred, new_df[i]], axis=0)

# %%
pred['target'] = pred['target'].astype('int64')

# %%
pred.tail()
# Out:
#         Territory X Date  target Territory
# 15248  Zimbabwe X 6/4/20      26  Zimbabwe
# 15249  Zimbabwe X 6/5/20      27  Zimbabwe
# 15250  Zimbabwe X 6/6/20      27  Zimbabwe
# 15251  Zimbabwe X 6/7/20      28  Zimbabwe
# 15252  Zimbabwe X 6/8/20      29  Zimbabwe

# %%
pred[['Territory X Date', 'target']].to_csv('Predictions 19-04 to 08-06 Update.csv', index=False)

# %% [markdown]
# ### Some things that might work better
#
# You can modify the 'cap' for specific territories if you have reasons to believe that it would be way more than predicted from the logistic model
#
# e.g:   train['cap'] = train['cap'].apply(lambda x: x+4500 if x>10000 else (x+500 if x>0 else x))
